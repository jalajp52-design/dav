# %%
#list

data=[1,2,43,4]
print(data)

print(data[0])      
print(data[-1])   
data[0]=4
print(data)

numbers = [0, 1, 2, 3, 4, 5]
print(numbers[1:2]) 
print(numbers[1:5:3])
# Out:
# [1, 2, 43, 4]
# 1
# 4
# [4, 2, 43, 4]
# [1]
# [1, 4]

# %%
#adding the data
fruits = ["apple", "banana"]
fruits.append("cherry")         
fruits.insert(1, "mango")  
print(fruits)   

fruits.extend(["grape", "kiwi"])
#removing the data  
fruits.remove("banana")     
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'cherry']
# ['apple', 'mango', 'cherry', 'grape', 'kiwi']

# %%
num=[1,3,4,5,6,4]
num.sort()
print(num)
# Out:
# [1, 3, 4, 4, 5, 6]

# %%
#tuple
data =(1.3,4.2,3.4,1.3)
print(data[0])
print(data[2])


print(data)
# Out:
# 1.3
# 3.4
# (1.3, 4.2, 3.4, 1.3)

# %%
data=(3,4,4,5,5,5)
print(numbers[2:5])
print(numbers[1:5])
# Out:
# [2, 3, 4]
# [1, 2, 3, 4]

# %%
original = (1, 2, 3,3,9,5,5)
new_tuple = original + (4,) 


temp_list = list(new_tuple)


temp_list.remove(2) 

temp_list.sort()

new_tuple = tuple(temp_list)

print(new_tuple)
# Out:
# (1, 3, 3, 4, 5, 5, 9)

# %%
#dictionaries
dict={
"name":"jalaj",
"language":"python",
"uni":"sc"

}
print(dict)
print(type(dict))
print(dict["name"])
# ADDING a new key-value pair
dict["id"] = "3321313"
print(dict) 
# Output: {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# UPDATING an existing key
dict["studying year"] = 2020
print(dict) # Output: 2020
del dict["name"]
print(dict)
# Out:
# ['Alice', 'Bob', 'Charlie']
# {'Alice': 95, 'Bob': 75, 'Charlie': 88}

# %%
scores = {"Charlie": 88, "Alice": 95, "Bob": 75}

# Returns a list of keys sorted alphabetically
sorted_keys = sorted(scores)
print(sorted_keys) # Output: ['Alice', 'Bob', 'Charlie']

# To create a new sorted DICTIONARY from this:
sorted_dict = {k: scores[k] for k in sorted_keys}
print(sorted_dict) scores = {"Charlie": 88, "Alice": 95, "Bob": 75}

# Returns a list of keys sorted alphabetically
sorted_keys = sorted(scores)
print(sorted_keys) # Output: ['Alice', 'Bob', 'Charlie']

# To create a new sorted DICTIONARY from this:
sorted_dict = {k: scores[k] for k in sorted_keys}
print(sorted_dict) # Output: {'Alice': 95, 'Bob': 75, 'Charlie': 88}

# %%
# Out:
# {'name': 'jalaj', 'language': 'python', 'uni': 'sc'}
# <class 'dict'>
# jalaj
# {'name': 'jalaj', 'language': 'python', 'uni': 'sc', 'id': '3321313'}
# {'name': 'jalaj', 'language': 'python', 'uni': 'sc', 'id': '3321313', 'studying year': 2020}
# {'language': 'python', 'uni': 'sc', 'id': '3321313', 'studying year': 2020}
