# %%
import pandas as pd
s = pd.Series([10,20,30,40])
print("Series:\n", s)
# Out:
# Series:
#  0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks  Age
# 0    Ram     85   20
# 1  Shyam     90   21
# 2  Mohan     78   19
# 3   Rita     88   22

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['Name', 'Marks', 'Age'], dtype='object')

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.head())
# Out:
#     Name  Marks  Age
# 0    Ram     85   20
# 1  Shyam     90   21
# 2  Mohan     78   19
# 3   Rita     88   22

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.tail())
# Out:
#     Name  Marks  Age
# 0    Ram     85   20
# 1  Shyam     90   21
# 2  Mohan     78   19
# 3   Rita     88   22

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.drop('Age', axis=1))
# Out:
#     Name  Marks
# 0    Ram     85
# 1  Shyam     90
# 2  Mohan     78
# 3   Rita     88

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.drop(2))
# Out:
#     Name  Marks  Age
# 0    Ram     85   20
# 1  Shyam     90   21
# 3   Rita     88   22

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df[df['Marks']>85])
# Out:
#     Name  Marks  Age
# 1  Shyam     90   21
# 3   Rita     88   22

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)
print(df.loc[1])
# Out:
# Name     Shyam
# Marks       90
# Age         21
# Name: 1, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.reindex([2,3,2,3,4]))
# Out:
#     Age  Marks   Name
# 2  19.0   78.0  Mohan
# 3  22.0   88.0   Rita
# 2  19.0   78.0  Mohan
# 3  22.0   88.0   Rita
# 4   NaN    NaN    NaN

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.iloc[1])
# Out:
# Name     Shyam
# Marks       90
# Age         21
# Name: 1, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.iloc[2])
# Out:
# Name     Mohan
# Marks       78
# Age         19
# Name: 2, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

df_num = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
print(df_num+df_num)
# Out:
#    A   B
# 0  2   8
# 1  4  10
# 2  6  12

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

df_num = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
s2 = pd.Series([1,1], index=['A','B'])
print(df_num+s2)
# Out:
#    A  B
# 0  2  5
# 1  3  6
# 2  4  7

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df[['Marks','Age']].sum())
# Out:
# Marks    341
# Age       82
# dtype: int64

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df[['Marks','Age']].apply(lambda x: x*2))
# Out:
#    Marks  Age
# 0    170   40
# 1    180   42
# 2    156   38
# 3    176   44

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.sort_values(by='Marks',ascending=False))
# Out:
#    Age  Marks   Name
# 1   21     90  Shyam
# 3   22     88   Rita
# 0   20     85    Ram
# 2   19     78  Mohan

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df['Marks'].rank())
# Out:
# 0    2.0
# 1    4.0
# 2    1.0
# 3    3.0
# Name: Marks, dtype: float64

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

df_dup = pd.DataFrame([100,200,300], index=['a','a','b'])
print(df_dup)
# Out:
#      0
# a  100
# a  200
# b  300

# %%
data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df.describe())
# Out:
#            Marks        Age
# count   4.000000   4.000000
# mean   85.250000  20.500000
# std     5.251984   1.290994
# min    78.000000  19.000000
# 25%    83.250000  19.750000
# 50%    86.500000  20.500000
# 75%    88.500000  21.250000
# max    90.000000  22.000000

# %%
import pandas as pd

data = {
    'Name': ['Ram', 'Shyam', 'Mohan', 'Rita'],
    'Marks': [85, 90, 78, 88],
    'Age': [20, 21, 19, 22]
}
df = pd.DataFrame(data)

print(df['Marks'].mean())
print(df['Marks'].max())
print(df['Marks'].min())
# Out:
# 85.25
# 90
# 78
