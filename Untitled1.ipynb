# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

x_mean = np.mean(x)
y_mean = np.mean(y)

print(x_mean)
print(y_mean)
#sum x-xmean*y-ymean/x-xmean*2
numratator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

m = numratator / denominator
c = y_mean - m * x_mean

print("Slope ", m)
print("Intercept ", c)
#y=mx+c
y_h=m*x_mean+c
y_h = m * x + c

mse = np.mean((y - y_h)** 2)
rss = np.sum((y - y_h) **2)


plt.plot(x, y_h)
plt.scatter(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# 3.0
# 6.0
# Slope  2.0
# Intercept  0.0

# %%
S
# Out:
# Slope: 0.13219307145963188
# Intercept: 25.309320191332077
# R-squared: 0.045082978409132016

# %%
import numpy as np
import matplotlib.pyplot as plt

# Given data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 8, 8, 10])

# Step 1: Calculate mean
x_mean = np.mean(x)
y_mean = np.mean(y)

# Step 2: Calculate slope (m) and intercept (c)
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean)**2)

m = numerator / denominator
c = y_mean - m * x_mean

print("Slope (m):", m)
print("Intercept (c):", c)

# Step 3: Predicted y values
y_pred = m * x + c

# Step 4: Calculate MSE and RSS
mse = np.mean((y - y_pred)**2)
rss = np.sum((y - y_pred)**2)

print("MSE:", mse)
print("RSS:", rss)

# Step 5: Predict for new x value
x_new = 6
y_new = m * x_new + c
print("Predicted y for x = 6 :", y_new)

# Step 6: Plot
plt.scatter(x, y, label="Original Data")
plt.plot(x, y_pred, color='red', label="Regression Line")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()
# Out:
# Slope (m): 2.0
# Intercept (c): 0.40000000000000036
# MSE: 0.6399999999999999
# RSS: 3.1999999999999997
# Predicted y for x = 6 : 12.4

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
)

# Generate synthetic dataset
X, y = make_classification(
    n_samples=200,
    n_features=5,
    n_informative=3,
    n_redundant=0,
    random_state=42
)

# Split train/test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train logistic regression
model = LogisticRegression(max_iter=100)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_pred_proba))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9666666666666667
# Precision: 1.0
# Recall: 0.9310344827586207
# F1 Score: 0.9642857142857143
# ROC AUC: 0.9699666295884317
# Confusion Matrix:
#  [[31  0]
#  [ 2 27]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

x = np.array([500, 800, 1000, 1200, 1500, 1800, 2000, 2200])
y = np.array([100, 150, 200, 230, 300, 350, 400, 420])

# Build linear regression model
slope, intercept, r, p, std_err = linregress(sqft, price)

print("Slope:", slope)
print("Intercept:", intercept)
print("R-value:", r)
print("P-value:", p)
print("Standard Error:", std_err)

# Prediction for new house (example: 1600 sqft)
new_x = 1600
predicted_y = slope * new_x + intercept
print("Predicted price for 1600 sqft house:", predicted_y)

# Plot
plt.scatter(x, price, label="Actual Prices")
plt.plot(x, slope * x + intercept, color='red', label="Regression Line")
plt.xlabel("Square Footage")
plt.ylabel("House Price ($1000s)")
plt.title("House Price Prediction using Linear Regression")

plt.show()
# Out:
# Slope: 0.1947731755424063
# Intercept: 0.9368836291912999
# R-value: 0.9983494886591722
# P-value: 1.1226846522555927e-08
# Standard Error: 0.0045742078848285544
# Predicted price for 1600 sqft house: 312.5739644970414

# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.linear_model import LinearRegression

# Step 1: Generate random X
np.random.seed(42)
X = np.random.uniform(0, 50, 100)

# Step 2: Generate Y using linear function with noise
noise = np.random.normal(0, 10, 100)
Y = 3*X + 5 + noise

# Reshape for sklearn
X_reshaped = X.reshape(-1,1)

# -------------------------------
# METHOD 1: Using scipy (statistical method)
# -------------------------------
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)

print("Method 1 (scipy)")
print("Slope:", slope)
print("Intercept:", intercept)
print("R-value:", r_value)
print("P-value:", p_value)
print("Standard Error:", std_err)

# -------------------------------
# METHOD 2: Using sklearn (ML method)
# -------------------------------
model = LinearRegression()
model.fit(X_reshaped, Y)

print("\nMethod 2 (sklearn)")
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
plt.plot(x,y)
